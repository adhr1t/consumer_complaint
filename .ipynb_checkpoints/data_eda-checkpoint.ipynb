# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import chi2

# %% [markdown]
# # Load in the data

# %%
df = pd.read_csv('complaints_cleaned.csv')
df = df.sample(n=4673)
df.head()
# Out:
#                                                 Product  \
# 7437                                       Student loan
# 2101  Credit reporting, credit repair services, or o...
# 7515                        Credit card or prepaid card
# 7122  Credit reporting, credit repair services, or o...
# 532                                     Debt collection
#
#                            Consumer_complaint_narrative  Category_ID
# 7437  This has been going on for about 20 years, my ...           15
# 2101  I was victim of Identity Theft, somebody stole...            6
# 7515  Due to the Covid-19 virus, I lost my job and f...            4
# 7122  XXXX  stated that they were able to verify a b...            6
# 532   For the past 6 month, I have received unwanted...            7

# %% [markdown]
# Create a dataframe and dictionary necessary for the term-product correlation code/

# %%
category_id_df = df[['Product', 'Category_ID']].drop_duplicates().sort_values('Category_ID')
category_to_id = dict(category_id_df.values)

# %% [markdown]
# # Visualize the Consumer Complaint counts

# %%
# plot frequencies
fig = plt.figure(figsize=(8,6))
df.groupby('Product').Consumer_complaint_narrative.count().plot.bar(ylim=0)
plt.show()

df.Product.value_counts()
# Out:
# Credit reporting, credit repair services, or other personal consumer reports    1786
# Debt collection                                                                  920
# Mortgage                                                                         511
# Credit card or prepaid card                                                      340
# Checking or savings account                                                      213
# Credit reporting                                                                 190
# Student loan                                                                     162
# Credit card                                                                      111
# Money transfer, virtual currency, or money service                               104
# Bank account or service                                                          102
# Vehicle loan or lease                                                             89
# Payday loan, title loan, or personal loan                                         63
# Consumer Loan                                                                     52
# Payday loan                                                                       15
# Prepaid card                                                                       6
# Money transfers                                                                    5
# Other financial service                                                            3
# Virtual currency                                                                   1
# Name: Product, dtype: int64

# %% [markdown]
# We're seeing lots of bias towards credit reporting, debt collection, and mortgage. We can fix this with resampling via SMOTE etc., but we want the algorithm to have high accuracy in predicting the majority classes, so we'll leave the training data as it is.

# %% [markdown]
# # Start using Consumer Complaint Narratives to determine keywords

# %% [markdown]
# Convert Consumer Complaint Narratives to TF-IDF features.

# %%
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')
features = tfidf.fit_transform(df.Consumer_complaint_narrative).toarray()
labels = df.Category_ID
features.shape
# Out:
# (4673, 13491)

# %% [markdown]
# Feed the TF-IDF features into feature_selection.chi2 so we can determine and print the words/phrases in the Consumer Complaint Narratives that are highly correlated with Products.

# %%
# iterate through the different products and print their most correlated unigrams and bigrams
for Product, category_id in sorted(category_to_id.items()):
  features_chi2 = chi2(features, labels == category_id)
  indices = np.argsort(features_chi2[0])    # indices of sorted features_chi2 array
  feature_names = np.array(tfidf.get_feature_names())[indices]
  unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
  bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
  print("# '{}':".format(Product))
  print("  . Most correlated unigrams:\n       . {}".format('\n       . '.join(unigrams[-2:])))
  print("  . Most correlated bigrams:\n       . {}".format('\n       . '.join(bigrams[-2:])))
# Out:
# # 'Bank account or service':
#   . Most correlated unigrams:
#        . overdraft
#        . payroll
#   . Most correlated bigrams:
#        . savings checking
#        . xxxx miles
# # 'Checking or savings account':
#   . Most correlated unigrams:
#        . overdraft
#        . bank
#   . Most correlated bigrams:
#        . chase bank
#        . checking account
# # 'Consumer Loan':
#   . Most correlated unigrams:
#        . dealer
#        . truck
#   . Most correlated bigrams:
#        . vehicle vehicle
#        . buying car
# # 'Credit card':
#   . Most correlated unigrams:
#        . card
#        . reward
#   . Most correlated bigrams:
#        . credit card
#        . use card
# # 'Credit card or prepaid card':
#   . Most correlated unigrams:
#        . rewards
#        . card
#   . Most correlated bigrams:
#        . american express
#        . credit card
# # 'Credit reporting':
#   . Most correlated unigrams:
#        . transunion
#        . equifax
#   . Most correlated bigrams:
#        . fraudulent inquiries
#        . equifax refused
# # 'Credit reporting, credit repair services, or other personal consumer reports':
#   . Most correlated unigrams:
#        . accounts
#        . report
#   . Most correlated bigrams:
#        . identity theft
#        . credit report
# # 'Debt collection':
#   . Most correlated unigrams:
#        . collection
#        . debt
#   . Most correlated bigrams:
#        . debt collection
#        . collect debt
# # 'Money transfer, virtual currency, or money service':
#   . Most correlated unigrams:
#        . coinbase
#        . paypal
#   . Most correlated bigrams:
#        . account coinbase
#        . paypal account
# # 'Money transfers':
#   . Most correlated unigrams:
#        . recipient
#        . western
#   . Most correlated bigrams:
#        . states xxxx
#        . western union
# # 'Mortgage':
#   . Most correlated unigrams:
#        . modification
#        . mortgage
#   . Most correlated bigrams:
#        . mortgage company
#        . loan modification
# # 'Other financial service':
#   . Most correlated unigrams:
#        . reissued
#        . 990
#   . Most correlated bigrams:
#        . car payment
#        . 990 00
# # 'Payday loan':
#   . Most correlated unigrams:
#        . payday
#        . ace
#   . Most correlated bigrams:
#        . email xxxxxxxxxxxx
#        . payday loan
# # 'Payday loan, title loan, or personal loan':
#   . Most correlated unigrams:
#        . counseling
#        . borrowed
#   . Most correlated bigrams:
#        . pay loan
#        . store manager
# # 'Prepaid card':
#   . Most correlated unigrams:
#        . instant
#        . withholding
#   . Most correlated bigrams:
#        . account months
#        . account withdraw
# # 'Student loan':
#   . Most correlated unigrams:
#        . loans
#        . navient
#   . Most correlated bigrams:
#        . qualifying payments
#        . loan forgiveness
# # 'Vehicle loan or lease':
#   . Most correlated unigrams:
#        . car
#        . vehicle
#   . Most correlated bigrams:
#        . ally financial
#        . title vehicle
# # 'Virtual currency':
#   . Most correlated unigrams:
#        . bonus
#        . 75
#   . Most correlated bigrams:
#        . 00 deposit
#        . 75 00
